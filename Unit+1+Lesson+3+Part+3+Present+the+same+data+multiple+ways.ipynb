# %% [markdown]
# <h3>FLS</h3>

# %% [markdown]
# Use folloiwng visualization types to answer below three questions
#
# + Comparison and ranking
# + Correlation
# + Distribution
# + Location-specific or geodata
# + Part-to-whole relationships and
# + Trends over time

# %% [markdown]
# <h2>Choose one variable and plot that variable four different ways.</h2>

# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot
fig=plt.figure()
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from scipy.stats import ttest_ind
from scipy import stats
import codecs
import datetime


# Read all data from source
df = pd.DataFrame()
df = pd.read_csv("C:/Users/aath/Dropbox/MAEN/Thankful/Data/fls/fls.csv",
                 index_col=False, encoding='iso-8859-1', nrows=238472, error_bad_lines=False)
#df['sale_year']= df['SaleDate'].str[4:]
#df['sale_year'] = pd.to_numeric(df['sale_year'], errors='coerce')

# help command
#df.head(2)
#df['Address'] = df['Address'].astype('str') 
#df.dtypes
#df['test'] = df.apply(lambda row: 2018 - row.Years, axis=1
#col_location = df.columns.get_loc('sale_year')
#y_axis = df.iloc[:,col_location]

# %%
df
# Out:
#                                       add sold3rd sale_date  \
# 0                                   77035      No  6/1/2010
# 1                                   77035      No  6/1/2010
# 2                                   77388      No  5/4/2010
# 3            1702 Winding Hollow Ln 77450      No  4/6/2010
# 4                20307 Ray Falls Dr 77375      No  4/6/2010
# 5            13619 Caney Springs Ln 77044      No  4/6/2010
# 6               2814 Oat Harvest Ct 77038      No  4/6/2010
# 7                     1006 Avenue J 77587      No  4/6/2010
# 8              1290 Yarrow Crest Ct 77085      No  4/6/2010
# 9               13155 Peppergate Ln 77044      No  4/6/2010
# 10          9415 Langley Springs Dr 77095      No  4/6/2010
# 11           13110 Highbury View Ct 77047      No  4/6/2010
# 12                7934 Millbrook Dr 77095      No  4/6/2010
# 13             3426 Owl Crossing Ln 77338      No  4/6/2010
# 14                 2518 Acadiana Ln 77586      No  4/6/2010
# ...

# %%
#data = pd.DataFrame(data, columns=['x', 'y'])

x1 = df.columns.get_loc('year')
y1 = df.columns.get_loc('final_bid')


x1df = df.iloc[:,x1]
y1df = df.iloc[:,y1]

data_x = pd.DataFrame({'x': x1df})
data_x = data_x[np.isfinite(df['year'])]

data_y = pd.DataFrame({'y': y1df})
data_y = data_x[np.isfinite(df['final_bid'])]   

data_xy = pd.DataFrame({'x': x1df,'y': y1df})
data_xy = data_xy.dropna()

# %%
plt.hist(data_x, normed=False, alpha=0.5)
# Out:
# (array([ 61733.,  56965.,  46710.,      0.,  25059.,  16135.,      0.,
#          13913.,  12841.,   5115.]),
#  array([ 0. ,  0.7,  1.4,  2.1,  2.8,  3.5,  4.2,  4.9,  5.6,  6.3,  7. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(data_x)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("x", data=data_xy, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=5)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("x", data=data_xy, aspect=4.0, kind='count',
                      order=range(2010, 2017))
    g.set_ylabels('Number of Sale')

# %% [markdown]
# <h2>Choose two continuous variables, and plot them three different ways.</h2>

# %%
#data = pd.DataFrame(data, columns=['x', 'y'])

x1 = df.columns.get_loc('open_bid')
y1 = df.columns.get_loc('final_bid')


x1df = df.iloc[:,x1]
y1df = df.iloc[:,y1]

data_x = pd.DataFrame({'x': x1df})
data_x = data_x[np.isfinite(df['open_bid'])]

data_y = pd.DataFrame({'y': y1df})
data_y = data_x[np.isfinite(df['final_bid'])]   

data_xy = pd.DataFrame({'x': x1df,'y': y1df})
data_xy = data_xy.dropna()
# Out:
# C:\Users\aath\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data_xy, kind='hex')

# %%
sns.set_style("whitegrid")
sns.boxplot(data=data_xy);

# %% [markdown]
# <h2>Choose one continuous variable and one categorical variable, and plot them six different ways..</h2>

# %%
df = pd.DataFrame()
df = pd.read_csv("C:/Users/aath/Dropbox/MAEN/Thankful/Data/fls/fls_hoa.csv",
                 index_col=False, encoding='iso-8859-1', nrows=238472, error_bad_lines=False)

# %%
#data = pd.DataFrame(data, columns=['x', 'y'])

x1 = df.columns.get_loc('year')
y1 = df.columns.get_loc('hourfinal')


x1df = df.iloc[:,x1]
y1df = df.iloc[:,y1]

data_x = pd.DataFrame({'x': x1df})
data_x = data_x[np.isfinite(df['year'])]

data_y = pd.DataFrame({'y': y1df})
data_y = data_x[np.isfinite(df['hourfinal'])]   

data_xy = pd.DataFrame({'x': x1df,'y': y1df})
data_xy = data_xy.dropna()

#data_xy = data_xy[(data_xy.T != 0).any()] delete when zero in entire row


data_xy = data_xy[data_xy.y != 0]

# %%
data_xy

# %%
# # Add one column of ones for pivot table
# df['ONES'] = pd.Series([1 for x in range(len(df.index))])

# # create pivot table
# table = pd.pivot_table(df,index=["zip"], values=["ONES"],
#                columns=["year"],aggfunc=np.sum, fill_value=0,margins=True)

# %%
# # flaten pivot or leveling it
# flat_df = pd.DataFrame(table.to_records())

# # Clean up the leveled table titles
# flat_df.columns = [hdr.replace("('ONES', ", "").replace(")", "") \
#                      for hdr in flat_df.columns]

# #Remove unnecessary columns and rows
# flat_df = flat_df.iloc[:, :-1]
# flat_df = flat_df[:-1]

# %%
# Set theme
sns.set_style('whitegrid')
 
# Violin plot
sns.violinplot(x='x', y='y', data=data_xy)

# %%
sns.swarmplot(x='x', y='y', data=data_xy)

# %%
# Set figure size with matplotlib
plt.figure(figsize=(10,6))
 
# Create plot
sns.violinplot(x='x',
               y='y', 
               data=data_xy, 
               inner=None) # Remove the bars inside the violins
 
sns.swarmplot(x='x', 
              y='y', 
              data=data_xy, 
              color='k', # Make points black
              alpha=0.7) # and slightly transparent
 
# Set title with matplotlib
plt.title('hour')
# Out:
# Text(0.5,1,'hour')

# %%
# 1. Enlarge the plot
plt.figure(figsize=(10,6))
 
sns.swarmplot(x='x', 
              y='y', 
              data=data_xy,split=True) # 2. Separate points by hue
              
 
# 4. Adjust the y-axis
plt.ylim(0, 260)
 
# 5. Place legend to the right
plt.legend(bbox_to_anchor=(1, 1), loc=2)
# Out:
# C:\Users\aath\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:2764: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
corr = data_xy.corr()
 
# Heatmap
sns.heatmap(corr)

# %%
sns.distplot(data_xy.y)

# %%
#pivot data = pd.DataFrame(data, columns=['x', 'y'])

x1 = flat_df.columns.get_loc('zip')
y1 = flat_df.columns.get_loc('2010')


x1df = flat_df.iloc[:,x1]
y1df = flat_df.iloc[:,y1]

# data_x = pd.DataFrame({'x': x1df})
# data_x = data_x[np.isfinite(df['zip'])]

# data_y = pd.DataFrame({'y': y1df})
# data_y = data_x[np.isfinite(df['final_bid'])]   


data_xy = pd.DataFrame({'x': x1df,'y': y1df})
data_xy = data_xy.dropna()
temp = data_xy.abs().sum(axis=1) > 10      
data_xy = data_xy.drop(temp)

#data_xy = data_xy[(data_xy.zip > 1).any()]

# data_xy = pd.DataFrame({'x': x1df,'y': y1df})
# data_xy = data_xy.dropna()
# See here for good samples of plots
# https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html
